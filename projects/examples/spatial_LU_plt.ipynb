# %%
# %matplotlib inline
import warnings
warnings.simplefilter("ignore") # Silence warnings
import hvplot.xarray
import xarray as xr
import cartopy.crs as ccrs

import matplotlib.pyplot as plt
import geoviews as gv
import holoviews as hv

import matplotlib.colors

import hvplot.pandas  # noqa
import hvplot.dask  # noq
hv.extension('bokeh')

import panel as pn
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %%
ds = xr.open_dataset("naturalveg2014.nc", decode_times=False).load()
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 1, longitude: 720, latitude: 360)
# Coordinates:
#   * time       (time) float64 1.164e+03
#   * longitude  (longitude) float64 -179.8 -179.2 -178.8 ... 178.8 179.2 179.8
#   * latitude   (latitude) float64 89.75 89.25 88.75 ... -88.75 -89.25 -89.75
# Data variables:
#     coverfrac  (time, latitude, longitude) float32 nan nan nan ... nan nan nan
# Attributes:
#     CDI:          Climate Data Interface version ?? (http://mpimet.mpg.de/cdi)
#     history:      Tue Oct 23 16:02:58 2018: cdo chname,transition,coverfrac F...
#     Conventions:  CF-1.6
#     CDO:          Climate Data Operators version 1.9.3 (http://mpimet.mpg.de/...

# %%
w_time = pn.widgets.IntSlider(name='time', start=0, end=10);
pt =  ds.isel(time=0).hvplot(x='longitude', y='latitude', z='landuse', cmap = 'Spectral_r')
#hvplot.save(pt, 'test.html')

# %%
pt
# Out:
# :Image   [longitude,latitude]   (landuse)
